# %%
import pandas as pd
print(pd.__version__)
df = pd.read_csv('../data/connections-dataset.csv')
print(df.columns)
# Out:
# 2.2.1
# Index(['from', 'to', 'weights', 'position'], dtype='object')

# %%
fast_arc_diagram(df, start_node='from', end_node='to')

# %%
fast_arc_diagram(df, start_node='from', end_node='to', weights='weights')

# %%
fast_arc_diagram(df, start_node='from', end_node='to', weights='weights', positions='position')

# %%
fast_arc_diagram(df, start_node='from', end_node='to', weights='weights', positions='position', invert_positions=True)
